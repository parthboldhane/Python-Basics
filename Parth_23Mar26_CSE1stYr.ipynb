# %%
fruits=["apple", "banana", "kiwi","coconut","walnut","Guava","Peach"]
fruits.append("Grapes")
fruits.append("Strawberry")
fruits.append("Orange")
print(fruits)
fruits.remove("walnut")
print(fruits)
fruits.extend(["Mango","Pineapple"])
print(fruits)
list2=["Cherry","Blueberry","Watermelon"]
fruits.append(list2)
list1=[1,2,3,4,5]
fruits.extend(list1)
print(fruits)  

fruits.pop(1)
print(fruits)
# Out:
# ['apple', 'banana', 'kiwi', 'coconut', 'walnut', 'Guava', 'Peach', 'Grapes', 'Strawberry', 'Orange']
# ['apple', 'banana', 'kiwi', 'coconut', 'Guava', 'Peach', 'Grapes', 'Strawberry', 'Orange']
# ['apple', 'banana', 'kiwi', 'coconut', 'Guava', 'Peach', 'Grapes', 'Strawberry', 'Orange', 'Mango', 'Pineapple']
# ['apple', 'banana', 'kiwi', 'coconut', 'Guava', 'Peach', 'Grapes', 'Strawberry', 'Orange', 'Mango', 'Pineapple', ['Cherry', 'Blueberry', 'Watermelon'], 1, 2, 3, 4, 5]
# ['apple', 'kiwi', 'coconut', 'Guava', 'Peach', 'Grapes', 'Strawberry', 'Orange', 'Mango', 'Pineapple', ['Cherry', 'Blueberry', 'Watermelon'], 1, 2, 3, 4, 5]
